# %% [markdown]
# <a href="https://colab.research.google.com/github/ArshnoorSinghh/DSAI/blob/main/IPL_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df= pd.read_csv("IPL.csv")

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
df.shape
# Out:
# (74, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
#how many cols have null values

# %%
df.isnull().sum() #shows that all cols have 0 null values
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
a=df['match_winner'].value_counts()
#to count which team won the most matches

sns.barplot(y=a.index, x= a.values, palette='rainbow')
plt.title("most match winner")
# Out:
# /tmp/ipykernel_1140/3798330231.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=a.index, x= a.values, palette='rainbow')
# Text(0.5, 1.0, 'most match winner')

# %%
#toss decision trend

# %%
a=df['toss_decision']

sns.countplot(a)
plt.title("toss decision")
# Out:
# Text(0.5, 1.0, 'toss decision')

# %%
#toss winner vs match winner
c=df[df['toss_winner']==df['match_winner']]['toss_winner'].count()
percentage= (c*100)/df.shape[0]
percentage
# Out:
# np.float64(48.648648648648646)

# %%
#how do teams win

df['won_by'].value_counts()
# Out:
# won_by
# Wickets    37
# Runs       37
# Name: count, dtype: int64

# %%
#most player of match

# %%
e=df['player_of_the_match'] .value_counts().head(10)

# %%
sns.barplot(y= e.index, x=e.values, palette='rainbow')
plt.title("most player of match")
# Out:
# /tmp/ipykernel_1140/612929150.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y= e.index, x=e.values, palette='rainbow')
# Text(0.5, 1.0, 'most player of match')

# %%
#2 top scorers

# %%
df['top_scorer'].value_counts()
# Out:
# top_scorer
# Jos Buttler            7
# Quinton de Kock        5
# Liam Livingstone       4
# Shubman Gill           4
# KL Rahul               4
# Ishan Kishan           3
# David Warner           3
# W. Saha                3
# Faf du Plessis         3
# Shikhar Dhawan         2
# Deepak Hooda           2
# MS Dhoni               2
# Abhishek Sharma        2
# Devon Conway           2
# Hardik Pandya          2
# Rahul Tripathi         2
# Mitchell Marsh         2
# Andre Russell          2
# Virat Kohli            2
# Aiden Markram          1
# Pat Cummins            1
# Kane Williamson        1
# Shivam Dube            1
# Suryakumar Yadav       1
# Shimron Hetmyer        1
# Sherfane Rutherford    1
# David Miller           1
# Tilak Varma            1
# Dinesh Karthik         1
# Nitish Rana            1
# Riyan Parag            1
# Sanju Samson           1
# Ruturaj Gaikwad        1
# Sai Sudharsan          1
# Yashasvi Jaiswal       1
# Moeen Ali              1
# ...

# %%
#10 best bowling figs

# %%
df.head(2)
# Out:
#    match_id           date                      venue    team1    team2  \
# 0         1  March 26,2022   Wankhede Stadium, Mumbai  Chennai  Kolkata
# 1         2  March 27,2022  Brabourne Stadium, Mumbai    Delhi   Mumbai
#
#    stage toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 0  Group     Kolkata         Field               131                5
# 1  Group       Delhi         Field               177                5
#
#    second_ings_score  second_ings_wkts match_winner   won_by  margin  \
# 0                133                 4      Kolkata  Wickets       6
# 1                179                 6        Delhi  Wickets       4
#
#   player_of_the_match    top_scorer  highscore   best_bowling  \
# 0         Umesh Yadav      MS Dhoni         50   Dwayne Bravo
# 1       Kuldeep Yadav  Ishan Kishan         81  Kuldeep Yadav
#
#   best_bowling_figure
# 0               3--20
# 1               3--18

# %%
df.groupby(by='best_bowling')['best_bowling'].count().sort_values(ascending=False).head(10)
# Out:
# best_bowling
# Yuzvendra Chahal    5
# Rashid Khan         4
# Kagiso Rabada       3
# Josh Hazlewood      3
# T Natarajan         3
# Kuldeep Yadav       3
# Avesh Khan          3
# Jasprit Bumrah      3
# Andre Russell       2
# Dwayne Bravo        2
# Name: best_bowling, dtype: int64

# %%
#who won highest margin by runs

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
f=df['margin'].max()

# %%
df[df['margin']==f]
# Out:
#     match_id        date                               venue    team1  team2  \
# 54        55  May 8,2022  Dr DY Patil Sports Academy, Mumbai  Chennai  Delhi
#
#     stage toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 54  Group       Delhi         Field               208                6
#
#     second_ings_score  second_ings_wkts match_winner won_by  margin  \
# 54                117                10      Chennai   Runs      91
#
#    player_of_the_match    top_scorer  highscore best_bowling  \
# 54        Devon Conway  Devon Conway         87    Moeen Ali
#
#    best_bowling_figure
# 54               3--13
